# %%
import pandas as pd #duplicates should be dropped only on unique IDs or values and not other columns #this is just an example showing
data = pd.read_excel("C:/Users/user/OneDrive/Desktop/data practice/python/data frames/salesdata.xlsx")
print(data)
# Out:
#                Order Date      Customer Name         State         Category  \
# 0     2014-03-01 00:00:00      Darren Powers         Texas  Office Supplies
# 1     2014-04-01 00:00:00      Phillina Ober      Illinois  Office Supplies
# 2     2014-04-01 00:00:00      Phillina Ober      Illinois  Office Supplies
# 3     2014-04-01 00:00:00      Phillina Ober      Illinois  Office Supplies
# 4     2014-05-01 00:00:00         Mick Brown  Pennsylvania  Office Supplies
# ...                   ...                ...           ...              ...
# 9989           30-12-2017  Patrick O'Donnell      New York       Technology
# 9990           30-12-2017  Patrick O'Donnell      New York  Office Supplies
# 9991           30-12-2017         Erica Bern    California  Office Supplies
# 9992           30-12-2017         Erica Bern    California  Office Supplies
# 9993           30-12-2017      Jill Matthias      Colorado  Office Supplies
#
# ...

# %%
print(data["State"].duplicated())
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 9989     True
# 9990     True
# 9991     True
# 9992     True
# 9993     True
# Name: State, Length: 9994, dtype: bool

# %%
print(data["State"].duplicated().sum())
# Out:
# 9945

# %%
print(data.drop_duplicates("State"))
# Out:
#                Order Date           Customer Name                 State  \
# 0     2014-03-01 00:00:00           Darren Powers                 Texas
# 1     2014-04-01 00:00:00           Phillina Ober              Illinois
# 4     2014-05-01 00:00:00              Mick Brown          Pennsylvania
# 5     2014-06-01 00:00:00        Lycoris Saunders            California
# 6     2014-06-01 00:00:00           Jack O'Briant               Georgia
# 7     2014-06-01 00:00:00           Maria Etezadi              Kentucky
# 18    2014-10-01 00:00:00          Anthony Jacobs              Virginia
# 20    2014-11-01 00:00:00             Seth Vernon              Delaware
# 21             13-01-2014         Chris Selesnick             Louisiana
# 26             13-01-2014       Natalie DeCherney        South Carolina
# 30             13-01-2014           Michael Moore                  Ohio
# 38             18-01-2014            David Wiener                Oregon
# ...
